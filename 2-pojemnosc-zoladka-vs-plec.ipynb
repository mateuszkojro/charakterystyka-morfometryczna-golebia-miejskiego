# %%
from utils import Dataset, init_notebook
init_notebook()
ds = Dataset.from_sheets()

# %%
_ = ds.compare_by_gender(x="Objętość żołądka mięśniowego (ml)")
# Out:
# Objętość żołądka mięśniowego (ml) female: mean=7.87, std=2.02
# Objętość żołądka mięśniowego (ml) male: mean=9.23, std=1.42
# Mann-Whitney 'u' aaa Objętość żołądka mięśniowego (ml) by gender: pvalue=0.15
