# %%
from utils import Dataset, init_notebook
init_notebook()
ds = Dataset.from_sheets()

# %%
ds.compare_by_gender(x="Masa ciała (kg)")
# Out:
# Masa ciała (kg) female: mean=0.29, std=0.09
# Masa ciała (kg) male: mean=0.32, std=0.06
# Mann-Whitney 'u' Masa ciała (kg) by gender: pvalue=0.44
# <Axes: xlabel='Płeć', ylabel='Masa ciała (kg)'>

# %%
ds.corr_body_mass(y="Masa serca (g)")
# Out:
# Masa ciała (kg): mean=0.31, std=0.07
# Masa serca (g): mean=4.43, std=1.64
# r^2=0.71, pvalue=0.00
# <Axes: xlabel='Masa ciała (kg)', ylabel='Masa serca (g)'>

# %%
ds.corr_body_mass(y="Długość głowy", hue="Płeć")
# Out:
# Masa ciała (kg): mean=0.31, std=0.07
# Długość głowy: mean=7.25, std=0.37
# r^2=-0.33, pvalue=0.15
# <Axes: xlabel='Masa ciała (kg)', ylabel='Długość głowy'>

# %%
ds.corr_body_mass(y="Długość skrzydła P")
# Out:
# Masa ciała (kg): mean=0.31, std=0.07
# Długość skrzydła P: mean=32.29, std=0.99
# r^2=0.14, pvalue=0.57
# <Axes: xlabel='Masa ciała (kg)', ylabel='Długość skrzydła P'>

# %%
ds.corr_body_mass(y="Masa wątroby (g)")
# Out:
# Masa ciała (kg): mean=0.31, std=0.07
# Masa wątroby (g): mean=7.74, std=1.95
# r^2=0.47, pvalue=0.04
# <Axes: xlabel='Masa ciała (kg)', ylabel='Masa wątroby (g)'>
