# %%
from utils import Dataset, init_notebook
# init_notebook()
ds = Dataset.from_sheets()

# %%
ds.linear_corr_pearson(x="Długość skrzydła P", y="Długość głowy", hue="Płeć")
# Out:
# Długość skrzydła P: mean=32.29, std=0.99
# Długość głowy: mean=7.25, std=0.37
# r^2=-0.01, pvalue=0.95
#     F r^2=-0.19, pvalue=0.69
#     M r^2=0.42, pvalue=0.15
# Saving plot to images/Correlation between Długość skrzydła P and Długość głowy.png
# <Axes: xlabel='Długość skrzydła P', ylabel='Długość głowy'>

# %%
ds.compare_by_gender(x="Długość skrzydła P")
# Out:
# Długość skrzydła P female: mean=31.46, std=0.63
# Długość skrzydła P male: mean=32.73, std=0.86
# Mann-Whitney 'u' Długość skrzydła P by gender: pvalue=0.01
# Saving plot to images/Długość skrzydła P by gender.png
# <Axes: xlabel='Płeć', ylabel='Długość skrzydła P'>

# %%
ds.compare_by_gender(x="Długość głowy")
# Out:
# Długość głowy female: mean=7.43, std=0.24
# Długość głowy male: mean=7.15, std=0.39
# Mann-Whitney 'u' Długość głowy by gender: pvalue=0.09
# Saving plot to images/Długość głowy by gender.png
# <Axes: xlabel='Płeć', ylabel='Długość głowy'>

# %% [markdown]
# # Coef of variance

# %%
print("Samce: ", 29.3/289.9)
print("Samice: ", 27.6/372.9)
# Out:
# Samce:  0.10106933425319077
# Samice:  0.07401448109412712
