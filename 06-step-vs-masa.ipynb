# %%
from utils import Dataset, init_notebook
init_notebook()
ds = Dataset.from_sheets()

# %%
g = ds.linear_corr_pearson(x="Masa ciała (g)", y="Średnica stępu L (cm)", hue="Płeć")
# Out:
# Masa ciała (g): mean=311.19, std=73.87
# 	F
# Średnica stępu L (cm): mean=0.45, std=0.06
# 	F
# r^2=0.21, pvalue=0.38
#     F r^2=0.17, pvalue=0.72
#     M r^2=0.08, pvalue=0.78
