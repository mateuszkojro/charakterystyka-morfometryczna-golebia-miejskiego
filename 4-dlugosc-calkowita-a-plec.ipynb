# %%
from utils import Dataset, init_notebook
init_notebook()
ds = Dataset.from_sheets()

# %%
ds.compare_by_gender(x="Długość ciała")
# Out:
# Długość ciała female: mean=36.31, std=0.67
# Długość ciała male: mean=37.88, std=1.38
# Mann-Whitney 'u' Długość ciała by gender: pvalue=0.01
# <Axes: xlabel='Płeć', ylabel='Długość ciała'>
