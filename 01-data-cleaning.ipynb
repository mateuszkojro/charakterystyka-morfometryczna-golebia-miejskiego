# %%
import pandas as pd
import seaborn as sns
from scipy import stats

# %%
df = pd.read_excel("./daria_computer_readable.xlsx")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_excel("./daria_computer_readable.xlsx")
#       2 df
#
# File ~/Sync/charakterystyka-morfometryczna-golebia-miejskiego/venv/lib/python3.13/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
g = sns.catplot(x="Płeć", y="Masa ciała (kg)", data=df, kind='violin', inner=None)
g = sns.swarmplot(x="Płeć", y="Masa ciała (kg)", data=df, ax=g.ax, color='k', alpha=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 g = sns.catplot(x="Płeć", y="Masa ciała (kg)", data=df, kind='violin', inner=None)
#       2 g = sns.swarmplot(x="Płeć", y="Masa ciała (kg)", data=df, ax=g.ax, color='k', alpha=1)
#
# NameError: name 'df' is not defined

# %%
sns.pairplot(df, diag_kind="kde", hue="Płeć")
# Out:
# /Users/mkojro/Sync/daria-inzynierka/venv/lib/python3.13/site-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/mkojro/Sync/daria-inzynierka/venv/lib/python3.13/site-packages/seaborn/utils.py:61: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /Users/mkojro/Sync/daria-inzynierka/venv/lib/python3.13/site-packages/IPython/core/events.py:82: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /Users/mkojro/Sync/daria-inzynierka/venv/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.to_csv("daria_computer_readable_x.xlsx", index=False)

# %%
import matplotlib.pyplot as plt

# Compute the correlation matrix (only numeric columns)
corr = df.corr(numeric_only=True)

# Plot the heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", square=Fa)
plt.title("Correlation Coefficient Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import matplotlib.pyplot as plt
#       3 # Compute the correlation matrix (only numeric columns)
# ----> 4 corr = df.corr(numeric_only=True)
#       6 # Plot the heatmap
#       7 plt.figure(figsize=(16, 12))
#
# NameError: name 'df' is not defined
