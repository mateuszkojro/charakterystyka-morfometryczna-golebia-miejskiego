# %%
from utils import Dataset, init_notebook
init_notebook()

# %%
ds = Dataset.from_sheets()
# Out:
# Replacing outliers with na

# %%
_ = ds.linear_corr_pearson(x="Głębokość klatki piersiowej (cm)",  y="Obwód klatki piersiowej (cm)", hue="Płeć")
# Out:
# Głębokość klatki piersiowej (cm): mean=6.23, std=0.62
# 	F
# Obwód klatki piersiowej (cm): mean=21.43, std=1.34
# 	F
# r^2=-0.18, pvalue=0.45
#     F r^2=-0.50, pvalue=0.25
#     M r^2=nan, pvalue=nan
# Saving plot to 'images/Correlation between Głębokość klatki piersiowej (cm) and Obwód klatki piersiowej (cm).png'

# %%
_ = ds.linear_corr_pearson(x="Masa serca (g)",  y="Obwód klatki piersiowej (cm)", hue="Płeć")
# Out:
# Masa serca (g): mean=4.14, std=1.04
# 	F
# Obwód klatki piersiowej (cm): mean=21.43, std=1.34
# 	F
# r^2=-0.30, pvalue=0.22
#     F r^2=nan, pvalue=nan
#     M r^2=nan, pvalue=nan
# Saving plot to 'images/Correlation between Masa serca (g) and Obwód klatki piersiowej (cm).png'

# %%
_ = ds.linear_corr_pearson(x="Masa wątroby (g)", y="Obwód klatki piersiowej (cm)", hue="Płeć")
# Out:
# Masa wątroby (g): mean=7.74, std=1.95
# 	F
# Obwód klatki piersiowej (cm): mean=21.43, std=1.34
# 	F
# r^2=0.03, pvalue=0.91
#     F r^2=-0.07, pvalue=0.88
#     M r^2=nan, pvalue=nan
# Saving plot to 'images/Correlation between Masa wątroby (g) and Obwód klatki piersiowej (cm).png'
