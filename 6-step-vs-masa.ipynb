# %%
from utils import Dataset, init_notebook
init_notebook()
ds = Dataset.from_sheets()

# %%
g = ds.linear_corr_pearson(x="Masa ciała (kg)", y="Średnica stępu/skoku LEWEGO", hue="Płeć")
# Out:
# Masa ciała (kg): mean=0.31, std=0.07
# Średnica stępu/skoku LEWEGO: mean=0.45, std=0.06
# r^2=0.21, pvalue=0.38
