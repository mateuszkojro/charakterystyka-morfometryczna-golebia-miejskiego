# %%
from utils import Dataset, init_notebook
# init_notebook()
ds = Dataset.from_sheets()
# Out:
# Replacing outliers with na

# %%
ds.linear_corr_pearson(x="Długość skrzydła P (cm)", y="Długość głowy (cm)", hue="Płeć")
# Out:
# Długość skrzydła P (cm): mean=32.29, std=0.99
# 	F
# Długość głowy (cm): mean=7.25, std=0.37
# 	F
# r^2=-0.01, pvalue=0.95
#     F r^2=-0.19, pvalue=0.69
#     M r^2=0.42, pvalue=0.15
# y = aaa  -0,01x + 7,41
# R² = 0,00
# Saving plot to 'images/Correlation between Długość skrzydła P (cm) and Długość głowy (cm).png'
# <Axes: xlabel='Długość skrzydła P (cm)', ylabel='Długość głowy (cm)'>

# %%
ds.compare_by_gender(x="Długość skrzydła P (cm)")
# Out:
# Długość skrzydła P (cm) female: mean=31.46, std=0.63, cv=0.02
# Długość skrzydła P (cm) male: mean=32.73, std=0.86, cv=0.03
# t-test Długość skrzydła P (cm) by gender: pvalue=0.00
# Saving plot to 'images/Długość skrzydła P (cm) by gender.png'
# <Axes: xlabel='Płeć', ylabel='Długość skrzydła P (cm)'>

# %%
ds.compare_by_gender(x="Długość głowy (cm)")
# Out:
# Długość głowy (cm) female: mean=7.43, std=0.24, cv=0.03
# Długość głowy (cm) male: mean=7.15, std=0.39, cv=0.05
# t-test Długość głowy (cm) by gender: pvalue=0.06
# Saving plot to 'images/Długość głowy (cm) by gender.png'
# <Axes: xlabel='Płeć', ylabel='Długość głowy (cm)'>

# %% [markdown]
# # Coef of variance

# %%
print("Samce: ", 29.3/289.9)
print("Samice: ", 27.6/372.9)
# Out:
# Samce:  0.10106933425319077
# Samice:  0.07401448109412712

# %%
ds.compare_by_gender("Długość dzioba (cm)")
# Out:
# Długość dzioba (cm) female: mean=1.85, std=0.21, cv=0.10
# Długość dzioba (cm) male: mean=1.94, std=0.13, cv=0.06
# t-test Długość dzioba (cm) by gender: pvalue=0.31
# Saving plot to 'images/Długość dzioba (cm) by gender.png'
# <Axes: xlabel='Płeć', ylabel='Długość dzioba (cm)'>

# %%
ds.compare_by_gender("Średnica stępu L (cm)")
# Out:
# Średnica stępu L (cm) female: mean=0.41, std=0.04, cv=0.08
# Średnica stępu L (cm) male: mean=0.47, std=0.06, cv=0.12
# t-test Średnica stępu L (cm) by gender: pvalue=0.00
# Saving plot to 'images/Średnica stępu L (cm) by gender.png'
# <Axes: xlabel='Płeć', ylabel='Średnica stępu L (cm)'>

# %%
ds.linear_corr_pearson(x="Długość ciała (cm)", y="Rozpiętość skrzydeł (cm)", hue="Płeć")
# Out:
# Długość ciała (cm): mean=37.33, std=1.39
# 	F
# Rozpiętość skrzydeł (cm): mean=68.68, std=2.27
# 	F
# r^2=0.65, pvalue=0.00
#     F r^2=-0.42, pvalue=0.35
#     M r^2=nan, pvalue=nan
# y = aaa  1,08x + 28,56
# R² = 0,42
# Saving plot to 'images/Correlation between Długość ciała (cm) and Rozpiętość skrzydeł (cm).png'
# <Axes: xlabel='Długość ciała (cm)', ylabel='Rozpiętość skrzydeł (cm)'>
