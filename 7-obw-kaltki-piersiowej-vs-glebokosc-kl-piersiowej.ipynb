# %%
from utils import Dataset, init_notebook
init_notebook()

# %%
ds = Dataset.from_sheets()

# %%
_ = ds.linear_corr_pearson(x="Głebokość klatki piersiowej",  y="Obwód klatki piersiowej", hue="Płeć")
# Out:
# Głebokość klatki piersiowej: mean=6.23, std=0.62
# Obwód klatki piersiowej: mean=21.64, std=1.62
# r^2=0.10, pvalue=0.67

# %%
_ = ds.linear_corr_pearson(x="Masa serca (g)",  y="Obwód klatki piersiowej", hue="Płeć")
# Out:
# Masa serca (g): mean=4.43, std=1.64
# Obwód klatki piersiowej: mean=21.64, std=1.62
# r^2=0.07, pvalue=0.78

# %%
_ = ds.linear_corr_pearson(x="Masa wątroby (g)", y="Obwód klatki piersiowej", hue="Płeć")
# Out:
# Masa wątroby (g): mean=7.74, std=1.95
# Obwód klatki piersiowej: mean=21.64, std=1.62
# r^2=0.06, pvalue=0.80
