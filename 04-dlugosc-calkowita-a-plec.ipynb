# %%
from utils import Dataset, init_notebook
# init_notebook()
ds = Dataset.from_sheets()
# Out:
# Replacing outliers with na

# %%
ds.compare_by_gender(x="Długość ciała (cm)")
# Out:
# Długość ciała (cm) female: mean=36.31, std=0.67, cv=0.02
# Długość ciała (cm) male: mean=37.88, std=1.38, cv=0.04
# t-test Długość ciała (cm) by gender: pvalue=0.00
# Saving plot to 'images/Długość ciała (cm) by gender.png'
# <Axes: xlabel='Płeć', ylabel='Długość ciała (cm)'>
