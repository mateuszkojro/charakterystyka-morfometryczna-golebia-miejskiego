# %%
from utils import Dataset, init_notebook
init_notebook()

# %%
ds = Dataset.from_sheets()
ds.fix_wing_span()

# %%
_ = ds.compare_by_gender(x="Rozpiętość skrzydeł (cm)")
# Out:
# Rozpiętość skrzydeł (cm) female: mean=66.81, std=1.90, cv=0.03
# Rozpiętość skrzydeł (cm) male: mean=69.68, std=1.77, cv=0.02
# Mann-Whitney 'u' Rozpiętość skrzydeł (cm) by gender: pvalue=0.01
# Saving plot to 'images/Rozpiętość skrzydeł (cm) by gender.png'

# %%
_ = ds.linear_corr_pearson(x="Długość ogona (cm)", y="Rozpiętość skrzydeł", hue="Płeć")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Sync/charakterystyka-morfometryczna-golebia-miejskiego/venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'Długość ogona'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ...
