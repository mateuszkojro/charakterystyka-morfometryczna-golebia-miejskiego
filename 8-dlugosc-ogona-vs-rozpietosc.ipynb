# %%
from utils import Dataset, init_notebook
init_notebook()

# %%
ds = Dataset.from_sheets()
ds.fix_wingspan()

# %%
_ = ds.linear_corr_pearson(x="Długość ogona", y="Rozpiętość skrzydeł", hue="Płeć")
# Out:
# Długość ogona: mean=12.18, std=0.66
# Rozpiętość skrzydeł: mean=68.57, std=2.28
# r^2=0.59, pvalue=0.01
